# %%
# Import necessary libraries
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#from tqdm import tqdm  # Import tqdm for progress bar


# Define a function to load data
def load_data(base_path):
    datasets = {}
    # List of filenames to load
    filenames = ['target_holdout', 'medclms_holdout_cleaned9.29', 'rxclms_holdout_cleaned9.29']

    for filename in filenames:
        dataset = pd.read_csv(f"{base_path}/{filename}.csv", low_memory=False, encoding='ISO-8859-1')
        dataset.fillna('N/A', inplace=True)
        datasets[filename] = dataset

    return datasets

# %%
# Define the base path where the data is located
base_path = "/Users/nathanzlomke/Downloads"

# Load the datasets using the defined function
datasets = load_data(base_path)
# Out:
# /var/folders/4s/dws9r14s699_2rwx3m1tvp5m0000gn/T/ipykernel_8499/867876001.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dataset.fillna('N/A', inplace=True)
# /var/folders/4s/dws9r14s699_2rwx3m1tvp5m0000gn/T/ipykernel_8499/867876001.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dataset.fillna('N/A', inplace=True)

# %%
datasets['rxclms_holdout_cleaned9.29'].rename(columns = {'ï»¿therapy_id':'therapy_id'}, inplace = 'True')

# %%
datasets['rxclms_holdout_cleaned9.29'].head()
# Out:
#               therapy_id      document_key       ndc_id service_date  \
# 0  1016317684-TAGRISSO-1  A195005006341001    228253950      4/10/19
# 1  1084085456-TAGRISSO-1  A195044963981001  29300024210      4/14/19
# 2  1016343065-TAGRISSO-1  A195078392391001  65862019899      4/17/19
# 3  1096559829-TAGRISSO-1  A195157798591001  50242006401      4/25/19
# 4  1016317684-TAGRISSO-1  A195223757081001  60505082901       5/2/19
#
#   process_date  Prescription_Filled_Duration  RX_Process_Duration  \
# 0      4/11/19                           -89                    1
# 1      4/15/19                           -78                    1
# 2      4/18/19                           -77                    1
# 3      4/26/19                           -85                    1
# 4       5/3/19                           -67                    1
#
#    pay_day_supply_cnt  rx_cost  tot_drug_cost_accum_amt  ... strength_meas  \
# 0                  30    13.70                  4725.09  ...      MG-100MG
# 1                  30     1.33                  1228.73  ...            MG
# 2                  90     5.36                     6.16  ...            MG
# 3                  30  9043.00                 27129.00  ...            MG
# 4                  30     6.10                  4738.79  ...       MCG/ACT
#
#   metric_strength specialty_ind clm_type ddi_ind anticoag_ind  \
# 0            25.0       NONSPCL       rx      No           No
# 1             5.0       NONSPCL       rx      No           No
# 2           100.0       NONSPCL       rx      No           No
# 3           150.0          SPCL       rx      No           No
# 4            50.0       NONSPCL       rx      No           No
#
#   diarrhea_treat_ind nausea_treat_ind seizure_treat_ind RX_Groupings
# 0                 No               No                No          CNS
# 1                 No               No                No       Cardio
# 2                 No               No                No          CNS
# 3                 No               No                No       Cancer
# 4                 No               No                No  Respiratory
#
# [5 rows x 27 columns]

# %%
# Merge all datasets together on 'therapy_id' as the primary key using an inner join
merged_data = datasets['target_holdout'].merge(datasets['rxclms_holdout_cleaned9.29'], on='therapy_id', how='left')

# %%
merged_data = merged_data.merge(datasets['medclms_holdout_cleaned9.29'], on='therapy_id', how='left')

# %%
merged_data.columns
# Out:
# Index(['therapy_id', 'medclm_key', 'clm_unique_key', 'primary_diag_cd',
#        'visit_date', 'Visit_Duration', 'diag_cd2', 'diag_cd3', 'diag_cd4',
#        'diag_cd5', 'diag_cd6', 'diag_cd7', 'diag_cd8', 'diag_cd9',
#        'process_date_x', 'MedProcess_Duration', 'reversal_ind', 'pot',
#        'util_cat', 'hedis_pot', 'clm_type_x', 'ade_diagnosis',
#        'seizure_diagnosis', 'pain_diagnosis', 'fatigue_diagnosis',
#        'nausea_diagnosis', 'hyperglycemia_diagnosis', 'constipation_diagnosis',
#        'diarrhea_diagnosis', 'PD_C00ÐD49_FLG', 'PD_D50ÐD89_FLG',
#        'PD_E00ÐE90_FLG', 'PD_G00ÐG99_FLG', 'PD_I00ÐI99_FLG', 'PD_J00ÐJ99_FLG',
#        'PD_M00ÐM99_FLG', 'PD_R00ÐR99_FLG', 'PD_Z00ÐZ99_FLG', 'PD_Other_FLG',
#        'NPD_C00ÐD49', 'NPD_D50ÐD89', 'NPD_E00ÐE90', 'NPD_G00ÐG99',
#        'NPD_I00ÐI99', 'NPD_J00ÐJ99', 'NPD_K00ÐK93', 'NPD_M00ÐM99',
#        'NPD_R00ÐR99', 'NPD_Z00ÐZ99', 'NPD_Other', 'NPD_SUM', 'document_key',
#        'ndc_id', 'service_date', 'process_date_y',
#        'Prescription_Filled_Duration', 'RX_Process_Duration',
#        'pay_day_supply_cnt', 'rx_cost', 'tot_drug_cost_accum_amt',
#        'reversal_iNod', 'mail_order_iNod', 'generic_ind', 'maint_ind',
#        'gpi_drug_group_desc', 'gpi_drug_class_desc', 'hum_drug_class_desc',
#        'strength_meas', 'metric_strength', 'specialty_ind', 'clm_type_y',
#        'ddi_ind', 'anticoag_ind', 'diarrhea_treat_ind', 'nausea_treat_ind',
#        'seizure_treat_ind', 'RX_Groupings', 'id', 'therapy_start_date',
#        'race_cd', 'est_age', 'sex_cd', 'cms_disabled_ind',
#        'cms_low_income_ind'],
#       dtype='object')

# %%
#There is no target variable for holdout data
'''# Convert 'Yes' to 1 and 'No' to 0 in the 'tgt_ade_dc_ind' column
merged_data['tgt_ade_dc_ind'] = merged_data['tgt_ade_dc_ind'].replace({'Yes': 1, 'No': 0})

# Print statistics about the column 'tgt_ade_dc_ind'
print("Statistics about 'tgt_ade_dc_ind' column:")
print(merged_data['tgt_ade_dc_ind'].describe())
'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tgt_ade_dc_ind'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/nathanzlomke/Documents/GitHub/ban5753-fall2023-rxdata/Humana-Mays Competition/NZ_humana_holdout_merge.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/nathanzlomke/Documents/GitHub/ban5753-fall2023-rxdata/Humana-Mays%20Competition/NZ_humana_holdout_merge.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # Convert 'Yes' to 1 and 'No' to 0 in the 'tgt_ade_dc_ind' column
# ----> <a href='vscode-notebook-cell:/Users/nathanzlomke/Documents/GitHub/ban5753-fall2023-rxdata/Humana-Mays%20Competition/NZ_humana_holdout_merge.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> merged_data['tgt_ade_dc_ind'] = merged_data['tgt_ade_dc_ind'].replace({'Yes': 1, 'No': 0})
#       <a href='vscode-notebook-cell:/Users/nathanzlomke/Documents/GitHub/ban5753-fall2023-rxdata/Humana-Mays%20Competition/NZ_humana_holdout_merge.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> # Print statistics about the column 'tgt_ade_dc_ind'
#       <a href='vscode-notebook-cell:/Users/nathanzlomke/Documents/GitHub/ban5753-fall2023-rxdata/Humana-Mays%20Competition/NZ_humana_holdout_merge.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> print("Statistics about 'tgt_ade_dc_ind' column:")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'tgt_ade_dc_ind'

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3878636 entries, 0 to 3878635
# Data columns (total 91 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   therapy_id                    object
#  1   medclm_key                    int64
#  2   clm_unique_key                float64
#  3   primary_diag_cd               object
#  4   visit_date                    object
#  5   Visit_Duration                object
#  6   diag_cd2                      object
#  7   diag_cd3                      object
#  8   diag_cd4                      object
#  9   diag_cd5                      object
#  10  diag_cd6                      object
#  11  diag_cd7                      object
#  12  diag_cd8                      object
#  13  diag_cd9                      object
#  14  process_date_x                object
#  15  MedProcess_Duration           int64
#  16  reversal_iNod_x               object
#  17  pot                           object
#  18  util_cat                      object
#  19  hedis_pot                     object
#  20  clm_type_x                    object
#  21  ade_diagnosis                 object
#  22  seizure_diagnosis             object
#  23  pain_diagnosis                object
#  24  fatigue_diagnosis             object
#  25  nausea_diagnosis              object
#  26  hyperglycemia_diagnosis       object
#  27  constipation_diagnosis        object
#  28  diarrhea_diagnosis            object
#  29  PD_C00ÐD49_FLG                int64
#  30  PD_D50ÐD89_FLG                int64
#  31  PD_E00ÐE90_FLG                int64
#  32  PD_G00ÐG99_FLG                int64
#  33  PD_I00ÐI99_FLG                int64
#  34  PD_J00ÐJ99_FLG                int64
#  35  PD_M00ÐM99_FLG                int64
#  36  PD_R00ÐR99_FLG                int64
#  37  PD_Z00ÐZ99_FLG                int64
#  38  PD_Other_FLG                  int64
#  39  NPD_C00ÐD49                   int64
#  40  NPD_D50ÐD89                   int64
#  41  NPD_E00ÐE90                   int64
#  42  NPD_G00ÐG99                   int64
#  43  NPD_I00ÐI99                   int64
#  44  NPD_J00ÐJ99                   int64
#  45  NPD_K00ÐK93                   int64
#  46  NPD_M00ÐM99                   int64
#  47  NPD_R00ÐR99                   int64
#  48  NPD_Z00ÐZ99                   int64
#  49  NPD_Other                     int64
#  50  NPD_SUM                       int64
#  51  Unnamed: 51                   object
#  52  Unnamed: 52                   object
#  53  Unnamed: 53                   object
#  54  Unnamed: 54                   object
#  55  document_key                  object
#  56  ndc_id                        int64
#  57  service_date                  object
#  58  process_date_y                object
#  59  Prescription_Filled_Duration  int64
#  60  RX_Process_Duration           int64
#  61  pay_day_supply_cnt            int64
#  62  rx_cost                       float64
#  63  tot_drug_cost_accum_amt       float64
#  64  reversal_iNod_y               object
#  65  mail_order_iNod               object
#  66  generic_ind                   object
#  67  maint_ind                     object
#  68  gpi_drug_group_desc           object
#  69  gpi_drug_class_desc           object
#  70  hum_drug_class_desc           object
#  71  strength_meas                 object
#  72  metric_strength               object
#  73  specialty_ind                 object
#  74  clm_type_y                    object
#  75  ddi_ind                       object
#  76  anticoag_ind                  object
#  77  diarrhea_treat_ind            object
#  78  nausea_treat_ind              object
#  79  seizure_treat_ind             object
#  80  RxGroupings                   object
#  81  id                            int64
#  82  therapy_start_date            object
#  83  therapy_end_date              object
#  84  Date Duration                 int64
#  85  tgt_ade_dc_ind                int64
#  86  race_cd                       object
#  87  est_age                       object
#  88  sex_cd                        object
#  89  cms_disabled_ind              object
#  90  cms_low_income_ind            object
# dtypes: float64(3), int64(31), object(57)
# memory usage: 2.6+ GB

# %%
merged_data.head()
# Out:
#               therapy_id   medclm_key  clm_unique_key primary_diag_cd  \
# 0  1066310426-TAGRISSO-1  35908472910    6.490000e+17          I70292
# 1  1066310426-TAGRISSO-1  35908472910    6.490000e+17          I70292
# 2  1066310426-TAGRISSO-1  35908472910    6.490000e+17          I70292
# 3  1066310426-TAGRISSO-1  35908472910    6.490000e+17          I70292
# 4  1066310426-TAGRISSO-1  35908472910    6.490000e+17          I70292
#
#   visit_date Visit_Duration diag_cd2 diag_cd3 diag_cd4 diag_cd5  ...  \
# 0    9/10/19         -128.0     I771     I739    R9431    Z7982  ...
# 1    9/10/19         -128.0     I771     I739    R9431    Z7982  ...
# 2    9/10/19         -128.0     I771     I739    R9431    Z7982  ...
# 3    9/10/19         -128.0     I771     I739    R9431    Z7982  ...
# 4    9/10/19         -128.0     I771     I739    R9431    Z7982  ...
#
#            id therapy_start_date therapy_end_date Date Duration  \
# 0  1066310426            1/16/20          2/15/20            30
# 1  1066310426            1/16/20          2/15/20            30
# 2  1066310426            1/16/20          2/15/20            30
# 3  1066310426            1/16/20          2/15/20            30
# 4  1066310426            1/16/20          2/15/20            30
#
#   tgt_ade_dc_ind  race_cd est_age sex_cd cms_disabled_ind cms_low_income_ind
# 0              0    White    74.0      M               No                 No
# 1              0    White    74.0      M               No                 No
# 2              0    White    74.0      M               No                 No
# 3              0    White    74.0      M               No                 No
# 4              0    White    74.0      M               No                 No
#
# [5 rows x 91 columns]

# %%
merged_data['therapy_id'].shape
# Out:
# (608123,)

# %%
merged_data.to_csv("CORRECTED_holdout_cleaned_humana_inner10-1.csv")
